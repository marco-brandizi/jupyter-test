# %% [markdown]
# # Accessing Knetminer from Jupyter

# %%
%endpoint http://knetminer-data.cyverseuk.org/lodestar/sparql
%display table
%show all

PREFIX bk: <http://knetminer.org/data/rdf/terms/biokno/>
PREFIX bkr: <http://knetminer.org/data/rdf/resources/>
PREFIX bka: <http://knetminer.org/data/rdf/terms/biokno/attributes/>
PREFIX bkg: <http://knetminer.org/data/rdf/resources/graphs/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX agri: <http://agrischemas.org/>
PREFIX bioschema: <http://bioschemas.org/>
PREFIX schema: <http://schema.org/>


SELECT ?gene ?geneAcc ?condLabel ?studyTitle ?study ?condTerm 
{
?gene a bk:Gene;
  dcterms:identifier ?geneAcc.

FILTER ( UCASE (?geneAcc) IN ( 
  'TRAESCS2D02G242700','TRAESCSU02G073600','TRAESCS7D02G050400',
  'TRAESCS6D02G393900','TRAESCS7D02G503700','TRAESCS7D02G431500',
  'TRAESCS1D02G090100','TRAESCS1D02G156000','TRAESCS2B02G046700',
  'TRAESCS4A02G318000','TRAESCS1A02G443400','TRAESCS7D02G241300',
  'TRAESCS6D02G107700','TRAESCS5D02G247200'
))  

?gene bioschema:expressedIn ?condition.
  
?expStatement a rdfs:Statement;
  rdf:subject ?gene;
  rdf:predicate bioschema:expressedIn;
  rdf:object ?condition;
  agri:score ?score;
  agri:evidence ?study.
                
?condition schema:prefName ?condLabel.
OPTIONAL { ?condition schema:additionalType ?condTerm. }
  
?study 
  dc:title ?studyTitle;
}
ORDER BY ?study ?gene
LIMIT 20
# Out:
# Endpoint set to: http://knetminer-data.cyverseuk.org/lodestar/sparql
# Display: table
# Result maximum size: unlimited
# <div class="krn-spql"><table><tr class=hdr><th>gene</th>
# <th>geneAcc</th>
# <th>condLabel</th>
# <th>studyTitle</th>
# <th>study</th>
# <th>condTerm</th></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, aleurone layer</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/plantontologyterm_po_0005360" target="_other">http://knetminer.org/data/rdf/resources/plantontologyterm_po_0005360</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, aleurone layer</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://www.yso.fi/onto/yso/p19450" target="_other">http://www.yso.fi/onto/yso/p19450</a></td></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, aleurone layer</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/ENVO_01000281" target="_other">http://purl.obolibrary.org/obo/ENVO_01000281</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, aleurone layer</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/PO_0005360" target="_other">http://purl.obolibrary.org/obo/PO_0005360</a></td></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, aleurone layer</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://www.cropontology.org/rdf/CO_321:0000434" target="_other">http://www.cropontology.org/rdf/CO_321:0000434</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/plantontologyterm_po_0006220" target="_other">http://knetminer.org/data/rdf/resources/plantontologyterm_po_0006220</a></td></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/plantontologyterm_po_0009089" target="_other">http://knetminer.org/data/rdf/resources/plantontologyterm_po_0009089</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://www.yso.fi/onto/yso/p19450" target="_other">http://www.yso.fi/onto/yso/p19450</a></td></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/PO_0006220" target="_other">http://purl.obolibrary.org/obo/PO_0006220</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://purl.obolibrary.org/obo/PO_0009089" target="_other">http://purl.obolibrary.org/obo/PO_0009089</a></td></tr><tr class=odd><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400</a></td>
# <td class=val>TRAESCS1A02G443400</td>
# <td class=val>14 day post anthesis, central endosperm</td>
# <td class=val>RNA-seq of wheat aleurone and starchy layers at 6, 9 and 14 days post anthesis</td>
# <td class=val><a href="http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344" target="_other">http://knetminer.org/data/rdf/resources/exp_E-GEOD-38344</a></td>
# <td class=val><a href="http://www.cropontology.org/rdf/CO_321:0000434" target="_other">http://www.cropontology.org/rdf/CO_321:0000434</a></td></tr><tr class=even><td class=val><a href="http://knetminer.org/data/rdf/resources/gene_traescs1a02g443400" target="_other">http://knetminer.org/data/rdf/resources
